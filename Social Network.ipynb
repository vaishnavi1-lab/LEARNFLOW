# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
sn=pd.read_csv("socialmedia.csv")

# %%
sn.head()
# Out:
#    User ID          Username   Platform  Post ID  \
# 0      101  @adventureSeeker  Instagram    82036
# 1      215   @foodieTraveler    Twitter    12463
# 2      303  @wellnessJourney   Facebook    45982
# 3      404     @fitnessFreak  Instagram    16572
# 4      521     @foodExplorer    Twitter    75589
#
#                                            Post Text    Post Timestamp  \
# 0  "Experiencing the thrill of a lifetime! #Adven...  30-07-2023 14:45
# 1    "Indulging in local delicacies! #FoodieTravels"  30-07-2023 19:30
# 2              "Finding peace and balance in nature!  30-07-2023 08:15
# 3                     "Pushing my limits in the gym!  30-07-2023 12:30
# 4      "Discovering unique flavors around the world!  30-07-2023 16:20
#
#    Likes/Reactions  Comments  Shares/Retweets          Hashtags  ...  \
# 0             1500       250              120    #AdventureTime  ...
# 1              850        70               50    #FoodieTravels  ...
# ...

# %%
sn.tail()
# Out:
#     User ID        Username   Platform  Post ID  \
# 34      817    @fashionGuru    YouTube    23879
# 35      940       @bookNerd  Goodreads    82714
# 36      108   @fitnessFreak    Twitter    95128
# 37      201  @foodieJourney  Instagram    80347
# 38      305       @techGeek   Facebook    20983
#
#                                      Post Text    Post Timestamp  \
# 34            "Unlocking the secrets of style!  30-07-2023 12:10
# 35        "Getting lost in the magic of books!  30-07-2023 16:25
# 36  "Pushing boundaries for a fitter tomorrow!  30-07-2023 20:00
# 37           "Embarking on a culinary journey!  30-07-2023 18:25
# 38      "Unraveling the marvels of technology!  30-07-2023 12:50
#
#     Likes/Reactions  Comments  Shares/Retweets         Hashtags  ...  \
# 34              520        70               40  #FashionInsider  ...
# 35              370        50               30   #BookObsession  ...
# 36              760       110               70   #FitnessJunkie  ...
# ...

# %%
sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User ID                39 non-null     int64
#  1   Username               39 non-null     object
#  2   Platform               39 non-null     object
#  3   Post ID                39 non-null     int64
#  4   Post Text              39 non-null     object
#  5   Post Timestamp         39 non-null     object
#  6   Likes/Reactions        39 non-null     int64
#  7   Comments               39 non-null     int64
#  8   Shares/Retweets        39 non-null     int64
#  9   Hashtags               39 non-null     object
#  10  Mentions               39 non-null     object
#  11  Media Type             39 non-null     object
#  12  Media URL              39 non-null     object
#  13  Post URL               39 non-null     object
# ...

# %%
sn.drop_duplicates()
# Out:
#     User ID           Username   Platform  Post ID  \
# 0       101   @adventureSeeker  Instagram    82036
# 1       215    @foodieTraveler    Twitter    12463
# 2       303   @wellnessJourney   Facebook    45982
# 3       404      @fitnessFreak  Instagram    16572
# 4       521      @foodExplorer    Twitter    75589
# 5       609    @wanderlustSoul   Facebook    24680
# 6       712          @techGeek    Twitter    36901
# 7       825      @petWhisperer  Instagram    98342
# 8       926      @bookwormLife   Facebook    57481
# 9       104        @foodPhotog  Instagram    20589
# 10      209      @artisticSoul    Twitter    73249
# 11      305       @musicAddict    Spotify    60912
# 12      427        @petRescuer  Instagram    14236
# 13      598       @natureLover  Instagram    95641
# 14      712    @techEnthusiast    Twitter    47560
# 15      825        @filmCritic    YouTube    65241
# 16      943       @fashionIcon  Instagram    30420
# ...

# %%
sn.dropna()
# Out:
#     User ID           Username   Platform  Post ID  \
# 0       101   @adventureSeeker  Instagram    82036
# 1       215    @foodieTraveler    Twitter    12463
# 2       303   @wellnessJourney   Facebook    45982
# 3       404      @fitnessFreak  Instagram    16572
# 4       521      @foodExplorer    Twitter    75589
# 5       609    @wanderlustSoul   Facebook    24680
# 6       712          @techGeek    Twitter    36901
# 7       825      @petWhisperer  Instagram    98342
# 8       926      @bookwormLife   Facebook    57481
# 9       104        @foodPhotog  Instagram    20589
# 10      209      @artisticSoul    Twitter    73249
# 11      305       @musicAddict    Spotify    60912
# 12      427        @petRescuer  Instagram    14236
# 13      598       @natureLover  Instagram    95641
# 14      712    @techEnthusiast    Twitter    47560
# 15      825        @filmCritic    YouTube    65241
# 16      943       @fashionIcon  Instagram    30420
# ...

# %%
sn['Post Timestamp']=pd.to_datetime(sn['Post Timestamp'])

# %%
sn.describe()
# Out:
#           User ID       Post ID  Likes/Reactions    Comments  Shares/Retweets  \
# count   39.000000     39.000000        39.000000   39.000000        39.000000
# mean   480.538462  54980.717949       967.179487  133.333333        76.923077
# std    276.570525  28586.874193       402.870939   82.695807        45.719617
# min    101.000000  12462.000000       370.000000   40.000000        30.000000
# 25%    215.000000  27616.500000       700.000000   80.000000        50.000000
# 50%    427.000000  59243.000000       890.000000  110.000000        60.000000
# 75%    712.000000  81140.500000      1135.000000  165.000000        90.000000
# max    943.000000  98342.000000      2200.000000  350.000000       220.000000
#
#        User Followers  User Following  User Engagement  User Interactions
# count       39.000000       39.000000        39.000000          39.000000
# mean     10458.974359      489.743590      1177.435897       11302.307692
# ...

# %% [markdown]
# # Exploration Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sn.hist(bins=20,figsize=(15,10))
plt.suptitle("Histogram for Numerical Variables")
plt.show()

# %%
sn['Post Timestamp']=pd.to_datetime(sn['Post Timestamp'])
sn['Month'] = sn['Post Timestamp'].dt.month
sn['Year'] = sn['Post Timestamp'].dt.year

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x='Month', data=sn, palette='viridis')
plt.title("Distribution of Posts Over Months")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4320\1734499133.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Month', data=sn, palette='viridis')

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x='Likes/Reactions', y='Platform', data=sn, palette='Set3')
plt.title("Boxplot of Likes/Reactions by Platform")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4320\2389934221.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Likes/Reactions', y='Platform', data=sn, palette='Set3')

# %%
hashtags = sn['Hashtags'].str.split(',').explode().str.strip().value_counts().head(10)
mentions = sn['Mentions'].str.split(',').explode().str.strip().value_counts().head(10)

# %%
plt.figure(figsize=(15, 5))
hashtags.plot(kind='bar', color='skyblue')
plt.title("Top 10 Hashtags")
plt.show()

# %%
plt.figure(figsize=(15, 5))
mentions.plot(kind='bar', color='lightcoral')
plt.title("Top 10 Mentions")
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x='User Activity', data=sn, palette='pastel')
plt.title("User Activity Distribution")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4320\1795434876.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='User Activity', data=sn, palette='pastel')

# %% [markdown]
# # Network Construction

# %%
import networkx as nx

# %%
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(sn['User ID'].unique())

# %%
# Add edges
edges = list(zip(sn['User ID'], sn['Mentions'].str.split(',')))
for edge in edges:
    source, targets = edge[0], edge[1]
    for target in targets:
        G.add_edge(source, target.strip())

# %%
# Visualize the network (optional)
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=50, font_size=8, font_color='black', alpha=0.7, node_color='skyblue', edge_color='gray')
plt.title("Social Network Graph")
plt.show()

# %% [markdown]
# # Identifying Key Metrices

# %%
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=500, tol=1e-6)

# Add centrality measures to the DataFrame
sn['Degree Centrality'] = sn['User ID'].map(degree_centrality)
sn['Betweenness Centrality'] = sn['User ID'].map(betweenness_centrality)
sn['Eigenvector Centrality'] = sn['User ID'].map(eigenvector_centrality)

# Display the DataFrame with centrality measures
print("DataFrame with Centrality Measures:")
print(sn[['User ID', 'Degree Centrality', 'Betweenness Centrality', 'Eigenvector Centrality']])

# Identify influential users based on centrality measures (customize threshold as needed)
influential_users = sn[sn['Degree Centrality'] > 0.05]['User ID'].tolist()

# Display influential users
print("\nInfluential Users:")
print(influential_users)
# Out:
# DataFrame with Centrality Measures:
#     User ID  Degree Centrality  Betweenness Centrality  Eigenvector Centrality
# 0       101           0.030303                     0.0                0.000176
# 1       215           0.030303                     0.0                0.000176
# 2       303           0.030303                     0.0                0.000176
# 3       404           0.030303                     0.0                0.000176
# 4       521           0.030303                     0.0                0.000176
# 5       609           0.030303                     0.0                0.000176
# 6       712           0.030303                     0.0                0.000176
# 7       825           0.030303                     0.0                0.000176
# 8       926           0.030303                     0.0                0.000176
# 9       104           0.030303                     0.0                0.000176
# ...

# %% [markdown]
# # Visualization

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_nodes_from(sn['User ID'].unique())

# Add edges
edges = list(zip(sn['User ID'], sn['Mentions'].str.split(',')))
for edge in edges:
    source, targets = edge[0], edge[1]
    for target in targets:
        G.add_edge(source, target.strip())

# Calculate degree centrality for node sizes
degree_centrality = nx.degree_centrality(G)
node_sizes = [2000 * degree_centrality[node] for node in G.nodes()]

# Identify influential users based on degree centrality threshold
influential_users = [user_id for user_id in G.nodes() if degree_centrality[user_id] > 0.05]

# Create a visualization
plt.figure(figsize=(12, 8))

# Draw the network graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=node_sizes, font_size=8, font_color='black', alpha=0.7, node_color='skyblue', edge_color='gray')

# Highlight influential users with a different color
nx.draw_networkx_nodes(G, pos, nodelist=influential_users, node_color='salmon', node_size=3000)

# Add labels and title
plt.title("Social Network Graph with Influential Users")
plt.show()

# %% [markdown]
# # Interpretation and Insights

# %%
print("Interpretation and Insights:")
print("\n1. **Influential Users:**")
print("   - Users with a degree centrality greater than 0.05 are considered influential.")
print(f"   - Identified influential users: {influential_users}")

# Community Structures
print("\n2. **Community Structures:**")
communities = list(nx.weakly_connected_components(G))
for i, community in enumerate(communities, 1):
    print(f"   - Community {i}: {list(community)}")

# Popular Hashtags and Mentions
print("\n3. **Popular Hashtags and Mentions:**")
hashtags = sn['Hashtags'].str.split(',').explode().str.strip().value_counts().head(5)
mentions = sn['Mentions'].str.split(',').explode().str.strip().value_counts().head(5)

print("   - Top 5 Hashtags:")
print(hashtags)

print("\n   - Top 5 Mentions:")
print(mentions)

# Temporal Analysis
print("\n4. **Temporal Analysis:**")
sn['Post Timestamp'] = pd.to_datetime(sn['Post Timestamp'])
sn['Month'] = sn['Post Timestamp'].dt.month

monthly_post_counts = sn.groupby('Month').size()

plt.figure(figsize=(12, 6))
monthly_post_counts.plot(kind='bar', color='skyblue')
plt.title("Monthly Post Distribution")
plt.xlabel("Month")
plt.ylabel("Number of Posts")
plt.show()
# Out:
# Interpretation and Insights:
#
# 1. **Influential Users:**
#    - Users with a degree centrality greater than 0.05 are considered influential.
#    - Identified influential users: ['None']
#
# 2. **Community Structures:**
#    - Community 1: [518, 903, 521, 522, 402, 404, 405, 926, 158, 802, 427, 940, 303, 943, 305, 817, 311, 825, 711, 712, 201, 209, 210, 725, 598, 215, 609, 101, 102, 104, 618, 108, 'None', 625]
#
# 3. **Popular Hashtags and Mentions:**
#    - Top 5 Hashtags:
# #Wanderlust        2
# #AdventureTime     1
# #FitnessJourney    1
# #TechInnovation    1
# #BookWorm          1
# Name: Hashtags, dtype: int64
#
#    - Top 5 Mentions:
# None    39
# Name: Mentions, dtype: int64
#
# 4. **Temporal Analysis:**
